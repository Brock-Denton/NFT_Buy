# %%
import pandas as pd 

import os 

from dotenv import load_dotenv

import requests 

import json 

load_dotenv()

api_key = os.getenv("BLOCKSPAN_API_KEY")

url = "https://api.blockspan.com/v1/exchanges/collectionsranking?chain=eth-main&exchange=opensea&ranking=seven_day_volume&page_size=25"

headers = {
    "accept": "application/json",
    "X-API-KEY": api_key
}

response = requests.get(url, headers=headers).json()

json_string = json.dumps(response)

json_data = json.loads(json_string)

for item in json_data['results']:

    key = item.get('key')
    contract_address = item['contracts'][0].get('contract_address')
    one_day_sales = item.get('one_day_sales')
    one_day_average_price = item.get('one_day_average_price')
    one_day_volume = item.get('one_day_volume')
    seven_day_average_price = item.get('seven_day_average_price')
    seven_day_sales = item.get('seven_day_sales')
    seven_day_volume = item.get('seven_day_volume')
    total_volume = item.get('total_volume')
    

    print(f"key: {key}")
    print(f"contract_address: {contract_address}")
    print(f"one_day_sales: {one_day_sales}")
    print(f"one_day_average_price: {one_day_average_price}")
    print(f"one_day_volume: {one_day_volume}")
    print(f"seven_day_average_price: {seven_day_average_price}")
    print(f"seven_day_sales: {seven_day_sales}")
    print(f"seven_day_volume: {total_volume}")
    print(f"total_volume: {total_volume}")
# Out:
# key: cockpunch
# contract_address: 0xc178994cb9b66307cd62db8b411759dd36d9c2ee
# one_day_sales: 609
# one_day_average_price: 1.101032280119851
# one_day_volume: 670.5286585929894
# seven_day_average_price: 1.3717190906280472
# seven_day_sales: 2655
# seven_day_volume: 3641.91418561746
# total_volume: 3641.91418561746
# key: cryptopunks
# contract_address: 0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# one_day_sales: 5
# one_day_average_price: 69.558
# one_day_volume: 347.79
# seven_day_average_price: 67.6796
# seven_day_sales: 50
# seven_day_volume: 1073286.5670093384
# total_volume: 1073286.5670093384
# key: art-blocks
# contract_address: 0xa7d8d9ef8d8ce8992df33d8b8cf4aebabd5bd270
# one_day_sales: 334
# one_day_average_price: 1.1083266167664667
# one_day_volume: 370.18108999999987
# seven_day_average_price: 1.597381050092739
# seven_day_sales: 1726
# seven_day_volume: 461032.1315977061
# total_volume: 461032.1315977061
# key: valhalla
# contract_address: 0x231d3559aa848bf10366fb9868590f01d34bf240
# one_day_sales: 1030
# one_day_average_price: 0.927559330096992
# one_day_volume: 955.3861099999017
# seven_day_average_price: 0.8114187101802353
# seven_day_sales: 3026
# seven_day_volume: 6187.623111137146
# total_volume: 6187.623111137146
# key: boredapeyachtclub
# contract_address: 0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d
# one_day_sales: 7
# one_day_average_price: 73.08488571428572
# one_day_volume: 511.5942
# seven_day_average_price: 73.00320897826087
# seven_day_sales: 23
# seven_day_volume: 695451.2373987382
# total_volume: 695451.2373987382
# key: mutant-ape-yacht-club
# contract_address: 0x60e4d786628fea6478f785a6d7e704777c86a7c6
# one_day_sales: 16
# one_day_average_price: 14.711525624999998
# one_day_volume: 235.38440999999997
# seven_day_average_price: 14.897473321100922
# seven_day_sales: 109
# seven_day_volume: 470291.15221087926
# total_volume: 470291.15221087926
# key: clonex
# contract_address: 0x49cf6f5d44e70224e2e23fdcdd2c053f30ada28b
# one_day_sales: 25
# one_day_average_price: 12.731892
# one_day_volume: 318.2973
# seven_day_average_price: 9.443725886960655
# seven_day_sales: 155
# seven_day_volume: 242761.57936137932
# total_volume: 242761.57936137932
# key: rtfkt-animus-egg
# contract_address: 0x6c410cf0b8c113dc6a7641b431390b11d5515082
# one_day_sales: 65
# one_day_average_price: 0.7844175384615383
# one_day_volume: 50.98713999999999
# seven_day_average_price: 1.0035616120074655
# seven_day_sales: 1205
# seven_day_volume: 1921.1486007289955
# total_volume: 1921.1486007289955
# key: rtfktmonolith
# contract_address: 0x6d4bbc0387dd4759eee30f6a482ac6dc2df3facf
# one_day_sales: 438
# one_day_average_price: 0.13769472257990867
# one_day_volume: 60.31028849
# seven_day_average_price: 0.49448559586077556
# seven_day_sales: 2399
# seven_day_volume: 13789.673096238905
# total_volume: 13789.673096238905
# key: dori-samurai
# contract_address: 0x6d9c17bc83a416bb992ccc671bebd98d7a76cfc3
# one_day_sales: 180
# one_day_average_price: 0.5138034388888887
# one_day_volume: 92.48461899999997
# seven_day_average_price: 0.28313593220193706
# seven_day_sales: 3309
# seven_day_volume: 936.8967996562083
# total_volume: 936.8967996562083
# key: otherdeed
# contract_address: 0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258
# one_day_sales: 55
# one_day_average_price: 2.8423567272727275
# one_day_volume: 156.32962
# seven_day_average_price: 2.409802674514383
# seven_day_sales: 381
# seven_day_volume: 361052.1758115943
# total_volume: 361052.1758115943
# key: azuki
# contract_address: 0xed5af388653567af2f388e6224dc7c4b3241c544
# one_day_sales: 8
# one_day_average_price: 15.018749999999999
# one_day_volume: 120.14999999999999
# seven_day_average_price: 13.590867625000001
# seven_day_sales: 64
# seven_day_volume: 270224.3653864565
# total_volume: 270224.3653864565
# key: light-years-selection-pass
# contract_address: 0xe31cc44e305955fa5965addb42641832e9a5502f
# one_day_sales: 3
# one_day_average_price: 30.083333333333332
# one_day_volume: 90.25
# seven_day_average_price: 30.853333333333335
# seven_day_sales: 27
# seven_day_volume: 833.0400000000001
# total_volume: 833.0400000000001
# key: pudgypenguins
# contract_address: 0xbd3531da5cf5857e7cfaa92426877b022e612cf8
# one_day_sales: 5
# one_day_average_price: 4.649
# one_day_volume: 23.245
# seven_day_average_price: 4.648048864864867
# seven_day_sales: 148
# seven_day_volume: 65373.75069516748
# total_volume: 65373.75069516748
# key: 3d-invisible-friends
# contract_address: 0x49c36afa15c7fdbd57ce3d61d80f39b6615a76ef
# one_day_sales: 48
# one_day_average_price: 0.4613962497916666
# one_day_volume: 22.147019989999997
# seven_day_average_price: 0.6930507707853335
# seven_day_sales: 963
# seven_day_volume: 1852.5978120227655
# total_volume: 1852.5978120227655
# key: abstraction-by-anon
# contract_address: 0xacb9d51b8e41df0a92f4cc497a2f8e1809ff9802
# one_day_sales: 38
# one_day_average_price: 1.5917368421052633
# one_day_volume: 60.486000000000004
# seven_day_average_price: 1.3216281333201865
# seven_day_sales: 431
# seven_day_volume: 712.093182951
# total_volume: 712.093182951
# key: love-tennis-art-collection
# contract_address: 0x4d928ab507bf633dd8e68024a1fb4c99316bbdf3
# one_day_sales: 14
# one_day_average_price: 2.118757142857143
# one_day_volume: 29.6626
# seven_day_average_price: 2.2192268359375014
# seven_day_sales: 256
# seven_day_volume: 568.1220700000001
# total_volume: 568.1220700000001
# key: doodles-official
# contract_address: 0x8a90cab2b38dba80c64b7734e58ee1db38b8992e
# one_day_sales: 10
# one_day_average_price: 7.34184
# one_day_volume: 73.4184
# seven_day_average_price: 7.765800317460318
# seven_day_sales: 63
# seven_day_volume: 152722.61997221957
# total_volume: 152722.61997221957
# key: ens
# contract_address: 0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85
# one_day_sales: 323
# one_day_average_price: 0.4918355086684212
# one_day_volume: 158.86286929990004
# seven_day_average_price: 0.16972368049246556
# seven_day_sales: 2866
# seven_day_volume: 73731.79794108194
# total_volume: 73731.79794108194
# key: cel-mates-crime-reports
# contract_address: 0xd0fabbba5fd95411a07bb2fdcf31295639376937
# one_day_sales: 56
# one_day_average_price: 0.5988537498214285
# one_day_volume: 33.53580999
# seven_day_average_price: 0.6865826998891079
# seven_day_sales: 662
# seven_day_volume: 1944.4965405401513
# total_volume: 1944.4965405401513
# key: friendship-bracelets-by-alexis-andre
# contract_address: 0x942bc2d3e7a589fe5bd4a5c6ef9727dfd82f5c8a
# one_day_sales: 118
# one_day_average_price: 0.658863765437339
# one_day_volume: 77.74592432160601
# seven_day_average_price: 0.4845491291025042
# seven_day_sales: 913
# seven_day_volume: 3048.1373254907057
# total_volume: 3048.1373254907057
# key: thememes6529
# contract_address: 0x33fd426905f149f8376e227d0c9d3340aad17af1
# one_day_sales: 79
# one_day_average_price: 0.2672191265836722
# one_day_volume: 21.1103110001101
# seven_day_average_price: 0.40639654782387186
# seven_day_sales: 1085
# seven_day_volume: 3241.8802956721233
# total_volume: 3241.8802956721233
# key: cel-mates-by-mcbess
# contract_address: 0x23f0dcecfe50f70d0c87578fd6a14f59900ab5e1
# one_day_sales: 63
# one_day_average_price: 0.5865319047619049
# one_day_volume: 36.951510000000006
# seven_day_average_price: 0.6669439123630675
# seven_day_sales: 639
# seven_day_volume: 426.1771600000002
# total_volume: 426.1771600000002
# key: bored-ape-kennel-club
# contract_address: 0xba30e5f9bb24caa003e9f2f0497ad287fdf95623
# one_day_sales: 6
# one_day_average_price: 7.19335
# one_day_volume: 43.1601
# seven_day_average_price: 6.579799898305086
# seven_day_sales: 59
# seven_day_volume: 113609.10352807409
# total_volume: 113609.10352807409
# key: sandbox
# contract_address: 0x50f5474724e0ee42d9a4e711ccfb275809fd6d4a
# one_day_sales: 52
# one_day_average_price: 1.3226945971153845
# one_day_volume: 68.78011905
# seven_day_average_price: 1.3623358287940315
# seven_day_sales: 279
# seven_day_volume: 158195.343355423
# total_volume: 158195.343355423
